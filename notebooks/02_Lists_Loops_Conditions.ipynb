# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudha233/python-basics/blob/main/notebooks/02_Lists_Loops_Conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 2 – Lists, Loops, and Conditions (Google Colab Edition)
# This notebook covers Python lists, loops, and conditional statements.

# %% [markdown]
# ## 1. Lists in Python
# ### 🔶 Task 1.1 – Create a weekly SST list

# %%
# TODO: Create your SST list and print first, last, and length.
sst = [25.5, 26, 27.5,28, 29.3, 30.5, 29.5]  # your SST list here
sst_1 = 25.5
sst_2 = 29.5

print("First value:", sst_1)
print("Last value:", sst_2)
print("Length of list:", len(sst))
# Out:
# First value: 25.5
# Last value: 29.5
# Length of list: 7

# %% [markdown]
# ## 2. Loops (for-loops)
# ### 🔶 Task 2.1 – Print each value

# %%
# TODO: Print each SST value with day number.
sst = [25.5, 26, 27.5,28, 29.3, 30.5, 29.5]
for i in range(len(sst)):
    temp = sst[i]
    # print Day X: value
    print("Day", i + 1, ":", temp)
print('anirudha')
# Out:
# Day 1 : 25.5
# Day 2 : 26
# Day 3 : 27.5
# Day 4 : 28
# Day 5 : 29.3
# Day 6 : 30.5
# Day 7 : 29.5
# anirudha

# %% [markdown]
# ## 3. Computing Mean using Loop
# ### 🔶 Task 3.1 – Compute mean SST manually

# %%
sst = [25.5, 26, 27.5,28, 29.3, 30.5, 29.5]
total = sum(sst)
print("total=", (sum(sst)))

for temp in sst:
    pass

mean_sst =total / len(sst)
print(f"Mean SST (loop):", mean_sst)
print(f"Mean SST (built-in):", sum(sst)/len(sst))
# Out:
# total= 196.3
# Mean SST (loop): 28.042857142857144
# Mean SST (built-in): 28.042857142857144

# %% [markdown]
# ## 4. Conditions: HOT or NORMAL days
# ### 🔶 Task 4.1 – Classify SST days

# %%
sst = [25.5, 26, 27.5,28, 29.3, 30.5, 29.5]
threshold = 28.5
hot_sst=()
normal_sst=()
for i in range(len(sst)):
    temp = sst[i]
    if temp > threshold:
        hot_sst += (temp,)
    else:
        normal_sst += (temp,)
for i in range(len(sst)):
    temp = sst[i]
    day = i + 1
    # TODO: write if condition here
print("Hot SST values:", hot_sst)
print("Normal SST values:", normal_sst)
# Out:
# Hot SST values: (29.3, 30.5, 29.5)
# Normal SST values: (25.5, 26, 27.5, 28)

# %% [markdown]
# ## 5. Filtering SST values
# ### 🔶 Task 5.1 – Create HOT and NORMAL SST lists

# %%
sst = [25.5, 26, 27.5,28, 29.3, 30.5, 29.5]
hot_sst = []
normal_sst = []
for i in range(len(sst)):
    temp = sst[i]
    if temp > 28.5:
       hot_sst.append(temp)
    else:
       normal_sst.append(temp)
print("Hot SST values:", hot_sst)
print("Normal SST values:", normal_sst)
# Out:
# Hot SST values: [29.3, 30.5, 29.5]
# Normal SST values: [25.5, 26, 27.5, 28]

# %% [markdown]
# ## 6. Mini Task – Rainfall classification
# ### 🔶 Task 6.1 – Classify rainfall intensity

# %%
rain = [0.0, 12.5, 34.0, 2.0, 0.0, 55.1, 8.4,]

no_rain = 0
light = 0
moderate = 0
heavy = 0
threshold_light = 8
threshold_moderate = 35
threshold_heavy =55.1
for r_value in rain:
    if r_value == 0:
        no_rain +=1

    elif r_value > 0 and r_value <= threshold_light:
            light +=1
    elif r_value > threshold_light and r_value <= threshold_moderate:
            moderate +=1
    else:
        heavy +=1


print("No rain days:", no_rain)
print("Light rain days:", light)
print("Moderate rain days:", moderate)
print("Heavy rain days:", heavy)
# Out:
# No rain days: 2
# Light rain days: 1
# Moderate rain days: 3
# Heavy rain days: 1

# %% [markdown]
# ## 7. Reflection
# Write 3–5 sentence answers to the reflection questions here.
# i understood append() method which built-in function that adds a single item to the end of an existinf list.
